# %%
import numpy
import pandas
import matplotlib
import pandas
import scipy
import sklearn
import torch

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.current_device())
print(torch.cuda.device(0))
print(torch.cuda.get_device_name(0))
# Out:
# True
# 1
# 0
# ...
# NVIDIA GeForce GTX 1650

# %%
# !nvidia-smi
# Out:
# Sun Sep 25 15:15:59 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 516.94       Driver Version: 516.94       CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   41C    P3    12W /  N/A |      0MiB /  4096MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
data = pd.read_csv(r"D:\Data Science Competition\train.csv")

# %% [markdown]
# count NA in columns:
# data.isna().sum()
#
# count NULL in columns:
# data.isnull().sum()

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# Drop all rows having at least one null values:
# data.dropna()
#
# drop all the rows whose columns’ values are all null:
# data.dropna(how='all')
#
# Drop rows where specific column values are null:
# data.dropna(subset=['colA', 'colC'])
#
# Drop rows with at least N non-missing values: define thresh
# data.dropna(thresh=len(df.columns)-1)

# %%
data = data.drop(columns=["MSZoning","Id"])

# %%
from sklearn.feature_selection import mutual_info_classif 
from sklearn.feature_selection import SelectKBest 
from sklearn.feature_selection import chi2 
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# autoencoder ,
# PCA ,
# covariance

# %%
data.corr().head()
# Out:
#              MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass     1.000000    -0.386347 -0.139781     0.032628    -0.059316
# LotFrontage   -0.386347     1.000000  0.426095     0.251646    -0.059213
# LotArea       -0.139781     0.426095  1.000000     0.105806    -0.005636
# OverallQual    0.032628     0.251646  0.105806     1.000000    -0.091932
# OverallCond   -0.059316    -0.059213 -0.005636    -0.091932     1.000000
#
#              YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  \
# MSSubClass    0.027850      0.040581    0.022936   -0.069836   -0.065649  ...
# LotFrontage   0.123349      0.088866    0.193458    0.233633    0.049900  ...
# LotArea       0.014228      0.013788    0.104160    0.214103    0.111170  ...
# OverallQual   0.572323      0.550684    0.411876    0.239666   -0.059119  ...
# OverallCond  -0.375983      0.073741   -0.128101   -0.046231    0.040229  ...
#
# ...

# %%
a = data.corr()

# %%
feature = [] 
corr_target = []
for i in a:
    if  a[i]["SalePrice"] >= 0.3 or a[i]["SalePrice"] < -0.3:
        feature.append(i)
        corr_target.append(a[i]["SalePrice"])

# %%
data[feature]
# Out:
#       LotFrontage  OverallQual  YearBuilt  YearRemodAdd  MasVnrArea  \
# 0            65.0            7       2003          2003       196.0
# 1            80.0            6       1976          1976         0.0
# 2            68.0            7       2001          2002       162.0
# 3            60.0            7       1915          1970         0.0
# 4            84.0            8       2000          2000       350.0
# ...           ...          ...        ...           ...         ...
# 1455         62.0            6       1999          2000         0.0
# 1456         85.0            6       1978          1988       119.0
# 1457         66.0            7       1941          2006         0.0
# 1458         68.0            5       1950          1996         0.0
# 1459         75.0            5       1965          1965         0.0
#
#       BsmtFinSF1  TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  FullBath  \
# 0            706          856       856       854       1710         2
# ...

# %%
corr_target
# Out:
# [0.7909816005838053,
#  0.5228973328794967,
#  0.5071009671113866,
#  0.6135805515591943,
#  0.6058521846919153,
#  0.7086244776126515,
#  0.5606637627484453,
#  0.5337231555820284,
#  0.6404091972583519,
#  0.6234314389183622,
#  1.0]
